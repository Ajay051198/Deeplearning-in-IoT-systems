# %%
from google.colab import drive
drive.mount('/content/drive/')
#imports
import os 
import pickle
import json
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

#tensorflow
import tensorflow as tf
from keras.layers import Dense, LSTM, Bidirectional, RNN
from keras.layers.embeddings import Embedding
from keras.models import Sequential
DATA_PATH = '/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/PP_Data/'
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
def getData(datasetName):
    X = np.load(f"{DATA_PATH}{datasetName}_X.npy", allow_pickle=True)
    Y = np.load(f"{DATA_PATH}{datasetName}_Y.npy", allow_pickle=True)
    enc_dec = np.load(f"{DATA_PATH}/{datasetName}_ENCDEC.npy", allow_pickle=True)
    return X, Y, enc_dec
X, y, (idx2act, idx2obs, act2idx, obs2idx) = getData('cairo')

# %%
def get_class_acc(X, y, model, idx2act):
  preds = np.array(np.argmax(model.predict(X, verbose=1), axis=-1), dtype=np.int32)
  targets = np.array(y, dtype=np.int32)
  m = confusion_matrix(targets, preds)
  fig, ax = plt.subplots(figsize=(13,10))
  sns.heatmap(m, annot=True, ax=ax)
  ax.set(xticklabels=idx2act, yticklabels=idx2act)
  plt.show()

# %%
def plot_history(dict):
  # summarize history for accuracy
  plt.plot(dict['accuracy'])
  plt.plot(dict['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'valid'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(dict['loss'])
  plt.plot(dict['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'valid'], loc='upper left')
  plt.show()

# %%
def run(X, y, idx2act, model, save_as, EPOCHS=10):
  print("-"*100)
  print(" > REPORT")
  print("-"*100)
  # TEST SPLIT
  X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.1)

  print('Training set distribution')
  fig, ax = plt.subplots(figsize=(15,5))
  train_y_df = pd.DataFrame({'y' : np.array(y_train, dtype=np.float32)})
  sns.countplot(train_y_df.y, ax=ax)
  ax.set(xticklabels=idx2act)
  plt.show()
  print('Test set distribution')
  fig2, ax2 = plt.subplots(figsize=(15,5))
  test_y_df = pd.DataFrame({'y' : np.array(y_test, dtype=np.float32)})
  sns.countplot(test_y_df.y, ax=ax2)
  ax2.set(xticklabels=idx2act)
  plt.show()
  
  print('Activity accuracy training set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_train, dtype=np.float32)), tf.convert_to_tensor(np.array(y_train, dtype=np.float32)), model, idx2act)
  print()
  print('Activity accuracy test set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), model, idx2act)
  
  # KFOLD SETUP
  X_train_np = np.array(X_train, dtype=np.float32)
  y_train_np = np.array(y_train, dtype=np.float32)
  skf = StratifiedKFold(n_splits=5, random_state=RANDOM_SEED, shuffle=True)
  # KFOLD LOOP
  overall_acc = []
  
  agg_hist={'loss': [], 'val_loss': [], 'accuracy': [], 'val_accuracy': []}
  for i, (train, test) in enumerate(skf.split(X_train_np, y_train_np)):
    print(f'Fold >> {i+1}')
    X_train_ = tf.convert_to_tensor(X_train_np[train], dtype=tf.float32)
    Y_train_ = tf.convert_to_tensor(y_train_np[train], dtype=tf.float32)
    X_test_ = tf.convert_to_tensor(X_train_np[test], dtype=tf.float32)
    Y_test_ = tf.convert_to_tensor(y_train_np[test], dtype=tf.float32)
    print(f"Begin training ...")

    #callbacks
    filepath = f"/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/{save_as}"
    saveModel = tf.keras.callbacks.ModelCheckpoint(
        filepath+"/cp.ckpt", monitor='val_loss', save_best_only=True, 
        save_weights_only=False, mode='auto', save_freq='epoch', options=None)


    history = model.fit(X_train_, Y_train_, epochs=EPOCHS, batch_size=64, verbose=1, callbacks=[saveModel], validation_split=0.2)
    agg_hist['loss'].extend(history.history['loss'])
    agg_hist['val_loss'].extend(history.history['val_loss'])
    agg_hist['accuracy'].extend(history.history['accuracy'])
    agg_hist['val_accuracy'].extend(history.history['val_accuracy'])
    print(f"Begin evalutaion ...")
    scores = model.evaluate(X_test_, Y_test_, batch_size=64, verbose=1)
    print('%s: %.2f%%' % (model.metrics_names[1], scores[1] * 100))
    overall_acc.append(scores[1]*100)
    print()

  model.save(filepath+".h5")
  print('HISTORY')
  plot_history(agg_hist)
  print()

  print('Test set evalutaion')
  scores = model.evaluate(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), batch_size=64, verbose=1)
  print('%s: %.2f%%' % (model.metrics_names[1], scores[1] * 100))
  print()
  print('Activity accuracy training set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_train, dtype=np.float32)), tf.convert_to_tensor(np.array(y_train, dtype=np.float32)), model, idx2act)
  print()
  print('Activity accuracy test set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), model, idx2act)

# %%
# biLSTM 
def get_biLSTM(INPUT_DIM, N_HIDDEN, MAX_LENGTH, NO_ACTIVITIES, OPTIMIZER):
  model = Sequential(name='biLSTM')
  model.add(Embedding(INPUT_DIM, N_HIDDEN, input_length=MAX_LENGTH, mask_zero=True))
  model.add(Bidirectional(LSTM(N_HIDDEN)))
  model.add(Dense(NO_ACTIVITIES, activation='softmax'))
  model.compile(loss='sparse_categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])
  model.summary()
  return model

# %%
#Arbitary high dim
INPUT_DIM = 1000 
#2n
N_HIDDEN = 64
MAX_LENGTH = 2000
NO_ACTIVITIES = len(idx2act)
OPTIMIZER = 'adam'

# %%
model = get_biLSTM(INPUT_DIM, N_HIDDEN, MAX_LENGTH, NO_ACTIVITIES, OPTIMIZER)
# Out:
# Model: "biLSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2000, 64)          64000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               66048
# _________________________________________________________________
# dense (Dense)                (None, 8)                 1032
# =================================================================
# Total params: 131,080
# Trainable params: 131,080
# Non-trainable params: 0
# _________________________________________________________________

# %%
#GO
run(X, y, idx2act, model, 'biLSTM_EP1')
# Out:
# ----------------------------------------------------------------------------------------------------
#  > REPORT
# ----------------------------------------------------------------------------------------------------
# Training set distribution
# Test set distribution
# Activity accuracy training set
# --------------------------------------------------------------------------------
# 29/29 [==============================] - 25s 845ms/step
# Activity accuracy test set
# --------------------------------------------------------------------------------
# 4/4 [==============================] - 3s 654ms/step
# Fold >> 1
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - 73s 7s/step - loss: 2.0274 - accuracy: 0.4527 - val_loss: 1.9246 - val_accuracy: 0.4497
# Epoch 2/10
# 10/10 [==============================] - 71s 7s/step - loss: 1.6959 - accuracy: 0.5084 - val_loss: 1.5625 - val_accuracy: 0.4497
# Epoch 3/10
# 10/10 [==============================] - 71s 7s/step - loss: 1.4555 - accuracy: 0.5084 - val_loss: 1.4419 - val_accuracy: 0.4497
# Epoch 4/10
# 10/10 [==============================] - 71s 7s/step - loss: 1.3218 - accuracy: 0.5186 - val_loss: 1.3263 - val_accuracy: 0.4966
# Epoch 5/10
# 10/10 [==============================] - 71s 7s/step - loss: 1.1793 - accuracy: 0.5929 - val_loss: 1.1653 - val_accuracy: 0.5772
# Epoch 6/10
# 10/10 [==============================] - 71s 7s/step - loss: 1.0005 - accuracy: 0.6959 - val_loss: 1.0520 - val_accuracy: 0.6510
# Epoch 7/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.9115 - accuracy: 0.7196 - val_loss: 0.9161 - val_accuracy: 0.6711
# Epoch 8/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.7785 - accuracy: 0.7432 - val_loss: 0.9296 - val_accuracy: 0.6510
# Epoch 9/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.7324 - accuracy: 0.7720 - val_loss: 0.8130 - val_accuracy: 0.7584
# Epoch 10/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.6872 - accuracy: 0.8108 - val_loss: 0.9654 - val_accuracy: 0.7114
# Begin evalutaion ...
# 3/3 [==============================] - 2s 585ms/step - loss: 0.8122 - accuracy: 0.7796
# accuracy: 77.96%
#
# Fold >> 2
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.8314 - accuracy: 0.7551 - val_loss: 0.7909 - val_accuracy: 0.7450
# Epoch 2/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.7101 - accuracy: 0.7703 - val_loss: 0.7273 - val_accuracy: 0.7181
# Epoch 3/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.6267 - accuracy: 0.7703 - val_loss: 0.6535 - val_accuracy: 0.7517
# Epoch 4/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.5629 - accuracy: 0.8125 - val_loss: 0.6119 - val_accuracy: 0.7852
# Epoch 5/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.5215 - accuracy: 0.8311 - val_loss: 0.5714 - val_accuracy: 0.8255
# Epoch 6/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.4969 - accuracy: 0.8480 - val_loss: 0.5727 - val_accuracy: 0.7987
# Epoch 7/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.4408 - accuracy: 0.8530 - val_loss: 0.5138 - val_accuracy: 0.8725
# Epoch 8/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.4146 - accuracy: 0.8666 - val_loss: 0.4759 - val_accuracy: 0.9060
# Epoch 9/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.3814 - accuracy: 0.8682 - val_loss: 0.4609 - val_accuracy: 0.8926
# Epoch 10/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.3576 - accuracy: 0.8784 - val_loss: 0.4560 - val_accuracy: 0.8792
# Begin evalutaion ...
# 3/3 [==============================] - 2s 596ms/step - loss: 0.4362 - accuracy: 0.8656
# accuracy: 86.56%
#
# Fold >> 3
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.4037 - accuracy: 0.8651 - val_loss: 0.4425 - val_accuracy: 0.8725
# Epoch 2/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.4004 - accuracy: 0.8668 - val_loss: 0.4172 - val_accuracy: 0.8725
# Epoch 3/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.3942 - accuracy: 0.8870 - val_loss: 0.3840 - val_accuracy: 0.8859
# Epoch 4/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.3630 - accuracy: 0.8786 - val_loss: 0.3508 - val_accuracy: 0.9060
# Epoch 5/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.3460 - accuracy: 0.8803 - val_loss: 0.3164 - val_accuracy: 0.9060
# Epoch 6/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.3379 - accuracy: 0.8853 - val_loss: 0.3337 - val_accuracy: 0.9060
# Epoch 7/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.3434 - accuracy: 0.8685 - val_loss: 0.3420 - val_accuracy: 0.8725
# Epoch 8/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.3179 - accuracy: 0.8752 - val_loss: 0.3229 - val_accuracy: 0.8926
# Epoch 9/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.3103 - accuracy: 0.8820 - val_loss: 0.3030 - val_accuracy: 0.9128
# Epoch 10/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.2860 - accuracy: 0.8988 - val_loss: 0.3005 - val_accuracy: 0.8926
# Begin evalutaion ...
# 3/3 [==============================] - 2s 604ms/step - loss: 0.3652 - accuracy: 0.9027
# accuracy: 90.27%
#
# Fold >> 4
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.2947 - accuracy: 0.9005 - val_loss: 0.3578 - val_accuracy: 0.8993
# Epoch 2/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.2764 - accuracy: 0.9039 - val_loss: 0.3561 - val_accuracy: 0.8859
# Epoch 3/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.2529 - accuracy: 0.9140 - val_loss: 0.3440 - val_accuracy: 0.8926
# Epoch 4/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.2359 - accuracy: 0.9157 - val_loss: 0.3281 - val_accuracy: 0.8993
# Epoch 5/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.2657 - accuracy: 0.9056 - val_loss: 0.3182 - val_accuracy: 0.8926
# Epoch 6/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.2672 - accuracy: 0.9157 - val_loss: 0.2865 - val_accuracy: 0.8926
# Epoch 7/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.2271 - accuracy: 0.9207 - val_loss: 0.3289 - val_accuracy: 0.8792
# Epoch 8/10
# 10/10 [==============================] - 73s 7s/step - loss: 0.2291 - accuracy: 0.9224 - val_loss: 0.3022 - val_accuracy: 0.8792
# Epoch 9/10
# 10/10 [==============================] - 73s 7s/step - loss: 0.2092 - accuracy: 0.9325 - val_loss: 0.3082 - val_accuracy: 0.8792
# Epoch 10/10
# 10/10 [==============================] - 73s 7s/step - loss: 0.1973 - accuracy: 0.9376 - val_loss: 0.3013 - val_accuracy: 0.8993
# Begin evalutaion ...
# 3/3 [==============================] - 2s 598ms/step - loss: 0.2659 - accuracy: 0.8973
# accuracy: 89.73%
#
# Fold >> 5
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - 73s 7s/step - loss: 0.2138 - accuracy: 0.9292 - val_loss: 0.3579 - val_accuracy: 0.8725
# Epoch 2/10
# 10/10 [==============================] - 73s 7s/step - loss: 0.2337 - accuracy: 0.9224 - val_loss: 0.3640 - val_accuracy: 0.8859
# Epoch 3/10
# 10/10 [==============================] - 73s 7s/step - loss: 0.2300 - accuracy: 0.9207 - val_loss: 0.3807 - val_accuracy: 0.8725
# Epoch 4/10
# 10/10 [==============================] - 73s 7s/step - loss: 0.2297 - accuracy: 0.9258 - val_loss: 0.3400 - val_accuracy: 0.8859
# Epoch 5/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.2111 - accuracy: 0.9292 - val_loss: 0.3499 - val_accuracy: 0.8859
# Epoch 6/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.1953 - accuracy: 0.9376 - val_loss: 0.3422 - val_accuracy: 0.8926
# Epoch 7/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.1755 - accuracy: 0.9444 - val_loss: 0.3399 - val_accuracy: 0.8792
# Epoch 8/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.1801 - accuracy: 0.9460 - val_loss: 0.3536 - val_accuracy: 0.8725
# Epoch 9/10
# 10/10 [==============================] - 72s 7s/step - loss: 0.1799 - accuracy: 0.9410 - val_loss: 0.3252 - val_accuracy: 0.8859
# Epoch 10/10
# 10/10 [==============================] - 71s 7s/step - loss: 0.1630 - accuracy: 0.9444 - val_loss: 0.4386 - val_accuracy: 0.8591
# Begin evalutaion ...
# 3/3 [==============================] - 2s 582ms/step - loss: 0.2785 - accuracy: 0.9243
# accuracy: 92.43%
#
# HISTORY
# Test set evalutaion
# 2/2 [==============================] - 1s 443ms/step - loss: 0.5034 - accuracy: 0.8269
# accuracy: 82.69%
#
# Activity accuracy training set
# --------------------------------------------------------------------------------
# 29/29 [==============================] - 25s 853ms/step
# Activity accuracy test set
# --------------------------------------------------------------------------------
# 4/4 [==============================] - 3s 655ms/step

# %%
load_from = f"/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/'biLSTM_EP1.h5"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-cb34811a2115> in <module>()
#       1 load_from = f"/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/'biLSTM_EP1.h5"
# ----> 2 new_model = tf.keras.models.load_model(load_from)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     184     filepath = path_to_string(filepath)
#     185     if isinstance(filepath, six.string_types):
# --> 186       loader_impl.parse_saved_model(filepath)
#     187       return saved_model_load.load(filepath, compile, options)
#     188
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     111                   (export_dir,
#     112                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 113                    constants.SAVED_MODEL_FILENAME_PB))
#     114
#     115
#
# OSError: SavedModel file does not exist at: /content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/'biLSTM_EP1.h5/{saved_model.pbtxt|saved_model.pb}
