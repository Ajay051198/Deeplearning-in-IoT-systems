# %% [markdown]
# # EXPERIMENT 4
# ---
# ### Model Architecture: biDirectional LSTM
# ### Dataset: Cairo
#
# ### Parameters
# - INPUT_DIM = 105 (arbitary, high dimension)
# - N_HIDDEN = 64
# - MAX_LENGTH = 2000 (fixed)
# - NO_ACTIVITIES = 8 (cairo fixed)
# - OPTIMIZER = ADAM (0.005)
# - TOTAL EPOCHS = 30

# %%
from google.colab import drive
drive.mount('/content/drive/')
#imports
import os 
import pickle
import json
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

#tensorflow
import tensorflow as tf
from keras.layers import Dense, LSTM, Bidirectional, RNN
from keras.layers.embeddings import Embedding
from keras.models import Sequential
DATA_PATH = '/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/PP_Data/'
# Out:
# Mounted at /content/drive/

# %%
def getData(datasetName):
    X = np.load(f"{DATA_PATH}{datasetName}_X.npy", allow_pickle=True)
    Y = np.load(f"{DATA_PATH}{datasetName}_Y.npy", allow_pickle=True)
    enc_dec = np.load(f"{DATA_PATH}/{datasetName}_ENCDEC.npy", allow_pickle=True)
    return X, Y, enc_dec
X, y, (idx2act, idx2obs, act2idx, obs2idx) = getData('cairo')

# %%
def get_class_acc(X, y, model, idx2act):
  preds = np.array(np.argmax(model.predict(X, verbose=1), axis=-1), dtype=np.int32)
  targets = np.array(y, dtype=np.int32)
  
  print("Classwise accuracy: ")
  totals = {}
  correct = {}
  for i in range(len(idx2act)):
    totals[i] = 1
    correct[i] = 0
  for each in targets: 
    totals[each]+=1
  for i in range(len(idx2act)):
    if totals[i] != 1:
      totals[i] -= 1
  for i, each in enumerate(preds): 
    if each == targets[i]:
        correct[each]+=1
  for i, each in enumerate(idx2act):
    print(f"Model accuracy for predicting {each}: {correct[i]}/{totals[i]} || {round(correct[i]/totals[i]*100, 2)}%")

  print('-'*120)
  m = confusion_matrix(targets, preds)
  fig, ax = plt.subplots(figsize=(13,10))
  sns.heatmap(m, annot=True, ax=ax)
  ax.set(xticklabels=idx2act, yticklabels=idx2act)
  plt.show()
  print('-'*120)

# %%
def plot_history(dict):
  # summarize history for accuracy
  plt.figure(figsize=(10,10))
  plt.plot(dict['accuracy'])
  plt.plot(dict['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'valid'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.figure(figsize=(10,10))
  plt.plot(dict['loss'])
  plt.plot(dict['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'valid'], loc='upper left')
  plt.show()

# %%
def run(X, y, idx2act, model, save_as, EPOCHS=10):
  print("-"*100)
  print(" > REPORT")
  print("-"*100)
  # TEST SPLIT
  X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.1)

  print('Training set distribution')
  fig, ax = plt.subplots(figsize=(15,5))
  train_y_df = pd.DataFrame({'y' : np.array(y_train, dtype=np.float32)})
  sns.countplot(train_y_df.y, ax=ax)
  ax.set(xticklabels=idx2act)
  plt.show()
  print('Test set distribution')
  fig2, ax2 = plt.subplots(figsize=(15,5))
  test_y_df = pd.DataFrame({'y' : np.array(y_test, dtype=np.float32)})
  sns.countplot(test_y_df.y, ax=ax2)
  ax2.set(xticklabels=idx2act)
  plt.show()
  
  print('Activity accuracy training set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_train, dtype=np.float32)), tf.convert_to_tensor(np.array(y_train, dtype=np.float32)), model, idx2act)
  print()
  print('Activity accuracy test set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), model, idx2act)
  
  # KFOLD SETUP
  X_train_np = np.array(X_train, dtype=np.float32)
  y_train_np = np.array(y_train, dtype=np.float32)
  skf = StratifiedKFold(n_splits=5, random_state=RANDOM_SEED, shuffle=True)
  # KFOLD LOOP
  overall_acc = []
  
  agg_hist={'loss': [], 'val_loss': [], 'accuracy': [], 'val_accuracy': []}
  for i, (train, test) in enumerate(skf.split(X_train_np, y_train_np)):
    print(f'Fold >> {i+1}')
    X_train_ = tf.convert_to_tensor(X_train_np[train], dtype=tf.float32)
    Y_train_ = tf.convert_to_tensor(y_train_np[train], dtype=tf.float32)
    X_test_ = tf.convert_to_tensor(X_train_np[test], dtype=tf.float32)
    Y_test_ = tf.convert_to_tensor(y_train_np[test], dtype=tf.float32)
    print(f"Begin training ...")

    #callbacks
    filepath = f"/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/{save_as}.h5"
    history = model.fit(X_train_, Y_train_, epochs=EPOCHS, batch_size=64, verbose=1, callbacks=[], validation_split=0.2)
    agg_hist['loss'].extend(history.history['loss'])
    agg_hist['val_loss'].extend(history.history['val_loss'])
    agg_hist['accuracy'].extend(history.history['accuracy'])
    agg_hist['val_accuracy'].extend(history.history['val_accuracy'])
    print(f"Begin evalutaion ...")
    scores = model.evaluate(X_test_, Y_test_, batch_size=64, verbose=1)
    print('%s: %.2f%%' % (model.metrics_names[1], scores[1] * 100))
    overall_acc.append(scores[1]*100)
    print()

  model.save(filepath)
  print('HISTORY')
  plot_history(agg_hist)
  print()

  print('Test set evalutaion')
  scores = model.evaluate(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), batch_size=64, verbose=1)
  print('%s: %.2f%%' % (model.metrics_names[1], scores[1] * 100))
  print()
  print('Activity accuracy training set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_train, dtype=np.float32)), tf.convert_to_tensor(np.array(y_train, dtype=np.float32)), model, idx2act)
  print()
  print('Activity accuracy test set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), model, idx2act)

# %%
# biLSTM 
def get_biLSTM(INPUT_DIM, N_HIDDEN, MAX_LENGTH, NO_ACTIVITIES, OPTIMIZER):
  model = Sequential(name='biLSTM')
  model.add(Embedding(INPUT_DIM, N_HIDDEN, input_length=MAX_LENGTH, mask_zero=True))
  model.add(Bidirectional(LSTM(N_HIDDEN)))
  model.add(Dense(NO_ACTIVITIES, activation='softmax'))
  model.compile(loss='sparse_categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])
  model.summary()
  return model

# %%
INPUT_DIM = 105 
#2n
N_HIDDEN = 64
MAX_LENGTH = 2000
NO_ACTIVITIES = len(idx2act)
OPTIMIZER = tf.keras.optimizers.Adam(learning_rate=0.005)

# %%
model = get_biLSTM(INPUT_DIM, N_HIDDEN, MAX_LENGTH, NO_ACTIVITIES, OPTIMIZER)
# Out:
# Model: "biLSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2000, 64)          6720
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               66048
# _________________________________________________________________
# dense (Dense)                (None, 8)                 1032
# =================================================================
# Total params: 73,800
# Trainable params: 73,800
# Non-trainable params: 0
# _________________________________________________________________

# %%
#GO
run(X, y, idx2act, model, 'biLSTM_EP1', 6)
# Out:
# ----------------------------------------------------------------------------------------------------
#  > REPORT
# ----------------------------------------------------------------------------------------------------
# Training set distribution
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Test set distribution
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Activity accuracy training set
# --------------------------------------------------------------------------------
# 29/29 [==============================] - 27s 926ms/step
# Classwise accuracy:
# Model accuracy for predicting Eat: 11/114 || 9.65%
# Model accuracy for predicting Leave_Home: 26/62 || 41.94%
# Model accuracy for predicting Other: 142/460 || 30.87%
# Model accuracy for predicting Sleep: 0/87 || 0.0%
# Model accuracy for predicting Take_medicine: 0/40 || 0.0%
# Model accuracy for predicting Use Toiltet: 3/27 || 11.11%
# Model accuracy for predicting Wake: 0/87 || 0.0%
# Model accuracy for predicting Work: 0/50 || 0.0%
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
#
# Activity accuracy test set
# --------------------------------------------------------------------------------
# 4/4 [==============================] - 3s 712ms/step
# Classwise accuracy:
# Model accuracy for predicting Eat: 0/13 || 0.0%
# Model accuracy for predicting Leave_Home: 1/7 || 14.29%
# Model accuracy for predicting Other: 21/51 || 41.18%
# Model accuracy for predicting Sleep: 0/10 || 0.0%
# Model accuracy for predicting Take_medicine: 0/4 || 0.0%
# Model accuracy for predicting Use Toiltet: 0/3 || 0.0%
# Model accuracy for predicting Wake: 0/10 || 0.0%
# Model accuracy for predicting Work: 0/6 || 0.0%
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# Fold >> 1
# Begin training ...
# Epoch 1/6
# 10/10 [==============================] - 78s 8s/step - loss: 1.6111 - accuracy: 0.4831 - val_loss: 1.2287 - val_accuracy: 0.5503
# Epoch 2/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.9732 - accuracy: 0.6706 - val_loss: 0.7618 - val_accuracy: 0.7181
# Epoch 3/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.6305 - accuracy: 0.7618 - val_loss: 0.6345 - val_accuracy: 0.7785
# Epoch 4/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.5204 - accuracy: 0.8074 - val_loss: 0.6932 - val_accuracy: 0.7785
# Epoch 5/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.4662 - accuracy: 0.8463 - val_loss: 0.4671 - val_accuracy: 0.8523
# Epoch 6/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.3942 - accuracy: 0.8395 - val_loss: 0.4372 - val_accuracy: 0.8658
# Begin evalutaion ...
# 3/3 [==============================] - 2s 653ms/step - loss: 0.4555 - accuracy: 0.8011
# accuracy: 80.11%
#
# Fold >> 2
# Begin training ...
# Epoch 1/6
# 10/10 [==============================] - 77s 8s/step - loss: 0.4059 - accuracy: 0.8395 - val_loss: 0.4130 - val_accuracy: 0.8188
# Epoch 2/6
# 10/10 [==============================] - 77s 8s/step - loss: 0.3070 - accuracy: 0.8784 - val_loss: 0.3410 - val_accuracy: 0.8591
# Epoch 3/6
# 10/10 [==============================] - 77s 8s/step - loss: 0.2622 - accuracy: 0.8986 - val_loss: 0.3675 - val_accuracy: 0.8523
# Epoch 4/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.2376 - accuracy: 0.9155 - val_loss: 0.3089 - val_accuracy: 0.8792
# Epoch 5/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.2136 - accuracy: 0.9274 - val_loss: 0.3388 - val_accuracy: 0.8658
# Epoch 6/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.1926 - accuracy: 0.9257 - val_loss: 0.3192 - val_accuracy: 0.8591
# Begin evalutaion ...
# 3/3 [==============================] - 2s 657ms/step - loss: 0.2995 - accuracy: 0.8763
# accuracy: 87.63%
#
# Fold >> 3
# Begin training ...
# Epoch 1/6
# 10/10 [==============================] - 77s 8s/step - loss: 0.2087 - accuracy: 0.9241 - val_loss: 0.2860 - val_accuracy: 0.8926
# Epoch 2/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.1949 - accuracy: 0.9241 - val_loss: 0.2959 - val_accuracy: 0.8859
# Epoch 3/6
# 10/10 [==============================] - 77s 8s/step - loss: 0.2263 - accuracy: 0.9191 - val_loss: 0.3222 - val_accuracy: 0.8591
# Epoch 4/6
# 10/10 [==============================] - 77s 8s/step - loss: 0.1841 - accuracy: 0.9191 - val_loss: 0.2872 - val_accuracy: 0.8993
# Epoch 5/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.1429 - accuracy: 0.9477 - val_loss: 0.3075 - val_accuracy: 0.9060
# Epoch 6/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.1361 - accuracy: 0.9545 - val_loss: 0.3004 - val_accuracy: 0.9060
# Begin evalutaion ...
# 3/3 [==============================] - 2s 646ms/step - loss: 0.2761 - accuracy: 0.9027
# accuracy: 90.27%
#
# Fold >> 4
# Begin training ...
# Epoch 1/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.1703 - accuracy: 0.9410 - val_loss: 0.3338 - val_accuracy: 0.9060
# Epoch 2/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.1222 - accuracy: 0.9646 - val_loss: 0.2991 - val_accuracy: 0.9195
# Epoch 3/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.2308 - accuracy: 0.9207 - val_loss: 0.3944 - val_accuracy: 0.8255
# Epoch 4/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.2065 - accuracy: 0.9123 - val_loss: 0.3480 - val_accuracy: 0.8725
# Epoch 5/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.1576 - accuracy: 0.9376 - val_loss: 0.3983 - val_accuracy: 0.8658
# Epoch 6/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.1320 - accuracy: 0.9460 - val_loss: 0.3537 - val_accuracy: 0.8792
# Begin evalutaion ...
# 3/3 [==============================] - 2s 635ms/step - loss: 0.2106 - accuracy: 0.9243
# accuracy: 92.43%
#
# Fold >> 5
# Begin training ...
# Epoch 1/6
# 10/10 [==============================] - 75s 8s/step - loss: 0.1320 - accuracy: 0.9545 - val_loss: 0.4021 - val_accuracy: 0.8658
# Epoch 2/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.1207 - accuracy: 0.9578 - val_loss: 0.4380 - val_accuracy: 0.8725
# Epoch 3/6
# 10/10 [==============================] - 78s 8s/step - loss: 0.1156 - accuracy: 0.9646 - val_loss: 0.4631 - val_accuracy: 0.8322
# Epoch 4/6
# 10/10 [==============================] - 77s 8s/step - loss: 0.0974 - accuracy: 0.9713 - val_loss: 0.4346 - val_accuracy: 0.8591
# Epoch 5/6
# 10/10 [==============================] - 77s 8s/step - loss: 0.0789 - accuracy: 0.9696 - val_loss: 0.4636 - val_accuracy: 0.8456
# Epoch 6/6
# 10/10 [==============================] - 76s 8s/step - loss: 0.0644 - accuracy: 0.9764 - val_loss: 0.4834 - val_accuracy: 0.8456
# Begin evalutaion ...
# 3/3 [==============================] - 2s 638ms/step - loss: 0.1041 - accuracy: 0.9622
# accuracy: 96.22%
#
# HISTORY
# Test set evalutaion
# 2/2 [==============================] - 1s 475ms/step - loss: 0.4405 - accuracy: 0.8750
# accuracy: 87.50%
#
# Activity accuracy training set
# --------------------------------------------------------------------------------
# 29/29 [==============================] - 27s 928ms/step
# Classwise accuracy:
# Model accuracy for predicting Eat: 102/114 || 89.47%
# Model accuracy for predicting Leave_Home: 62/62 || 100.0%
# Model accuracy for predicting Other: 450/460 || 97.83%
# Model accuracy for predicting Sleep: 83/87 || 95.4%
# Model accuracy for predicting Take_medicine: 34/40 || 85.0%
# Model accuracy for predicting Use Toiltet: 24/27 || 88.89%
# Model accuracy for predicting Wake: 83/87 || 95.4%
# Model accuracy for predicting Work: 50/50 || 100.0%
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
#
# Activity accuracy test set
# --------------------------------------------------------------------------------
# 4/4 [==============================] - 3s 741ms/step
# Classwise accuracy:
# Model accuracy for predicting Eat: 12/13 || 92.31%
# Model accuracy for predicting Leave_Home: 7/7 || 100.0%
# Model accuracy for predicting Other: 45/51 || 88.24%
# Model accuracy for predicting Sleep: 7/10 || 70.0%
# Model accuracy for predicting Take_medicine: 3/4 || 75.0%
# Model accuracy for predicting Use Toiltet: 2/3 || 66.67%
# Model accuracy for predicting Wake: 9/10 || 90.0%
# Model accuracy for predicting Work: 6/6 || 100.0%
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
