# %% [markdown]
# # EXPERIMENT 1
# ---
# ### Model Architecture: biDirectional LSTM
# ### Dataset: Cairo
#
# ### Parameters
# - INPUT_DIM = 1000 (chosen arbitary, high dimension)
# - N_HIDDEN = 64
# - MAX_LENGTH = 2000 (fixed)
# - NO_ACTIVITIES = 8 (cairo fixed)
# - OPTIMIZER = ADAM
# - TOTAL EPOCHS = 50

# %%
from google.colab import drive
drive.mount('/content/drive/')
#imports
import os 
import pickle
import json
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

#tensorflow
import tensorflow as tf
from keras.layers import Dense, LSTM, Bidirectional, RNN
from keras.layers.embeddings import Embedding
from keras.models import Sequential
DATA_PATH = '/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/PP_Data/'
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
def getData(datasetName):
    X = np.load(f"{DATA_PATH}{datasetName}_X.npy", allow_pickle=True)
    Y = np.load(f"{DATA_PATH}{datasetName}_Y.npy", allow_pickle=True)
    enc_dec = np.load(f"{DATA_PATH}/{datasetName}_ENCDEC.npy", allow_pickle=True)
    return X, Y, enc_dec
X, y, (idx2act, idx2obs, act2idx, obs2idx) = getData('cairo')

# %%
def get_class_acc(X, y, model, idx2act):
  preds = np.array(np.argmax(model.predict(X, verbose=1), axis=-1), dtype=np.int32)
  targets = np.array(y, dtype=np.int32)
  
  print("Classwise accuracy: ")
  totals = {}
  correct = {}
  for i in range(len(idx2act)):
    totals[i] = 1
    correct[i] = 0
  for each in targets: 
    totals[each]+=1
  for i in range(len(idx2act)):
    if totals[i] != 1:
      totals[i] -= 1
  for i, each in enumerate(preds): 
    if each == targets[i]:
        correct[each]+=1
  for i, each in enumerate(idx2act):
    print(f"Model accuracy for predicting {each}: {correct[i]}/{totals[i]} || {round(correct[i]/totals[i]*100, 2)}%")

  print('-'*120)
  m = confusion_matrix(targets, preds)
  fig, ax = plt.subplots(figsize=(13,10))
  sns.heatmap(m, annot=True, ax=ax)
  ax.set(xticklabels=idx2act, yticklabels=idx2act)
  plt.show()
  print('-'*120)

# %%
def plot_history(dict):
  # summarize history for accuracy
  plt.figure(figsize=(10,10))
  plt.plot(dict['accuracy'])
  plt.plot(dict['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'valid'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.figure(figsize=(10,10))
  plt.plot(dict['loss'])
  plt.plot(dict['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'valid'], loc='upper left')
  plt.show()

# %%
def run(X, y, idx2act, model, save_as, EPOCHS=10):
  print("-"*100)
  print(" > REPORT")
  print("-"*100)
  # TEST SPLIT
  X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.1)

  print('Training set distribution')
  fig, ax = plt.subplots(figsize=(15,5))
  train_y_df = pd.DataFrame({'y' : np.array(y_train, dtype=np.float32)})
  sns.countplot(train_y_df.y, ax=ax)
  ax.set(xticklabels=idx2act)
  plt.show()
  print('Test set distribution')
  fig2, ax2 = plt.subplots(figsize=(15,5))
  test_y_df = pd.DataFrame({'y' : np.array(y_test, dtype=np.float32)})
  sns.countplot(test_y_df.y, ax=ax2)
  ax2.set(xticklabels=idx2act)
  plt.show()
  
  print('Activity accuracy training set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_train, dtype=np.float32)), tf.convert_to_tensor(np.array(y_train, dtype=np.float32)), model, idx2act)
  print()
  print('Activity accuracy test set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), model, idx2act)
  
  # KFOLD SETUP
  X_train_np = np.array(X_train, dtype=np.float32)
  y_train_np = np.array(y_train, dtype=np.float32)
  skf = StratifiedKFold(n_splits=5, random_state=RANDOM_SEED, shuffle=True)
  # KFOLD LOOP
  overall_acc = []
  
  agg_hist={'loss': [], 'val_loss': [], 'accuracy': [], 'val_accuracy': []}
  for i, (train, test) in enumerate(skf.split(X_train_np, y_train_np)):
    print(f'Fold >> {i+1}')
    X_train_ = tf.convert_to_tensor(X_train_np[train], dtype=tf.float32)
    Y_train_ = tf.convert_to_tensor(y_train_np[train], dtype=tf.float32)
    X_test_ = tf.convert_to_tensor(X_train_np[test], dtype=tf.float32)
    Y_test_ = tf.convert_to_tensor(y_train_np[test], dtype=tf.float32)
    print(f"Begin training ...")

    #callbacks
    filepath = f"/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/{save_as}"
    saveModel = tf.keras.callbacks.ModelCheckpoint(
        filepath+"/cp.ckpt", monitor='val_loss', save_best_only=True, 
        save_weights_only=False, mode='auto', save_freq='epoch', options=None)


    history = model.fit(X_train_, Y_train_, epochs=EPOCHS, batch_size=64, verbose=1, callbacks=[saveModel], validation_split=0.2)
    agg_hist['loss'].extend(history.history['loss'])
    agg_hist['val_loss'].extend(history.history['val_loss'])
    agg_hist['accuracy'].extend(history.history['accuracy'])
    agg_hist['val_accuracy'].extend(history.history['val_accuracy'])
    print(f"Begin evalutaion ...")
    scores = model.evaluate(X_test_, Y_test_, batch_size=64, verbose=1)
    print('%s: %.2f%%' % (model.metrics_names[1], scores[1] * 100))
    overall_acc.append(scores[1]*100)
    print()

  model.save(filepath+".h5")
  print('HISTORY')
  plot_history(agg_hist)
  print()

  print('Test set evalutaion')
  scores = model.evaluate(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), batch_size=64, verbose=1)
  print('%s: %.2f%%' % (model.metrics_names[1], scores[1] * 100))
  print()
  print('Activity accuracy training set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_train, dtype=np.float32)), tf.convert_to_tensor(np.array(y_train, dtype=np.float32)), model, idx2act)
  print()
  print('Activity accuracy test set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), model, idx2act)

# %%
# biLSTM 
def get_biLSTM(INPUT_DIM, N_HIDDEN, MAX_LENGTH, NO_ACTIVITIES, OPTIMIZER):
  model = Sequential(name='biLSTM')
  model.add(Embedding(INPUT_DIM, N_HIDDEN, input_length=MAX_LENGTH, mask_zero=True))
  model.add(Bidirectional(LSTM(N_HIDDEN)))
  model.add(Dense(NO_ACTIVITIES, activation='softmax'))
  model.compile(loss='sparse_categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])
  model.summary()
  return model

# %%
#Arbitary high dim
INPUT_DIM = 1000 
#2n
N_HIDDEN = 64
MAX_LENGTH = 2000
NO_ACTIVITIES = len(idx2act)
OPTIMIZER = 'adam'

# %%
model = get_biLSTM(INPUT_DIM, N_HIDDEN, MAX_LENGTH, NO_ACTIVITIES, OPTIMIZER)
# Out:
# Model: "biLSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2000, 64)          64000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               66048
# _________________________________________________________________
# dense (Dense)                (None, 8)                 1032
# =================================================================
# Total params: 131,080
# Trainable params: 131,080
# Non-trainable params: 0
# _________________________________________________________________

# %%
#GO
run(X, y, idx2act, model, 'biLSTM_EP1')
# Out:
# ----------------------------------------------------------------------------------------------------
#  > REPORT
# ----------------------------------------------------------------------------------------------------
# Training set distribution
# Test set distribution
# Activity accuracy training set
# --------------------------------------------------------------------------------
# 29/29 [==============================] - 36s 1s/step
# Classwise accuracy:
# Model accuracy for predicting Eat: 0/114 || 0.0%
# Model accuracy for predicting Leave_Home: 3/62 || 4.84%
# Model accuracy for predicting Other: 51/460 || 11.09%
# Model accuracy for predicting Sleep: 49/87 || 56.32%
# Model accuracy for predicting Take_medicine: 0/40 || 0.0%
# Model accuracy for predicting Use Toiltet: 0/27 || 0.0%
# Model accuracy for predicting Wake: 0/87 || 0.0%
# Model accuracy for predicting Work: 2/50 || 4.0%
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
#
# Activity accuracy test set
# --------------------------------------------------------------------------------
# 4/4 [==============================] - 4s 922ms/step
# Classwise accuracy:
# Model accuracy for predicting Eat: 0/13 || 0.0%
# Model accuracy for predicting Leave_Home: 0/7 || 0.0%
# Model accuracy for predicting Other: 6/51 || 11.76%
# Model accuracy for predicting Sleep: 3/10 || 30.0%
# Model accuracy for predicting Take_medicine: 1/4 || 25.0%
# Model accuracy for predicting Use Toiltet: 0/3 || 0.0%
# Model accuracy for predicting Wake: 0/10 || 0.0%
# Model accuracy for predicting Work: 0/6 || 0.0%
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# Fold >> 1
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - ETA: 0s - loss: 2.0206 - accuracy: 0.5084 WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/biLSTM_EP1/cp.ckpt/assets
# 10/10 [==============================] - 150s 15s/step - loss: 2.0206 - accuracy: 0.5084 - val_loss: 1.9035 - val_accuracy: 0.4497
# Epoch 2/10
# 10/10 [==============================] - ETA: 0s - loss:
INFO:tensorflow:Assets written to: /content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/biLSTM_EP1/cp.ckpt/assets
# 10/10 [==============================] - 147s 15s/step - loss: 0.2414 - accuracy: 0.9140 - val_loss: 0.3587 - val_accuracy: 0.8658
# Begin evalutaion ...
# 3/3 [==============================] - 2s 830ms/step - loss: 0.2814 - accuracy: 0.9081
# accuracy: 90.81%
#
# Fold >> 5
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - ETA: 0s - loss: 0.2481 - accuracy: 0.9022 INFO:tensorflow:Assets written to: /content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/biLSTM_EP1/cp.ckpt/assets
# 10/10 [==============================] - 146s 15s/step - loss: 0.2481 - accuracy: 0.9022 - val_loss: 0.3858 - val_accuracy: 0.8792
# Epoch 2/10
# 10/10 [==============================] - ETA: 0s - loss: 0.2341 - accuracy: 0.9140 INFO:tensorflow:Assets written to: /content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/biLSTM_EP1/cp.ckpt/assets
# 10/10 [==============================] - 149s 15s/step - loss: 0.2341 - accuracy: 0.9140 - val_loss: 0.3662 - val_accuracy: 0.8725
# Epoch 3/10
# 10/10 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.9157 INFO:tensorflow:Assets written to: /content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/biLSTM_EP1/cp.ckpt/assets
# 10/10 [==============================] - 149s 15s/step - loss: 0.2252 - accuracy: 0.9157 - val_loss: 0.3585 - val_accuracy: 0.8859
# Epoch 4/10
# 10/10 [==============================] - 124s 12s/step - loss: 0.2188 - accuracy: 0.9241 - val_loss: 0.3700 - val_accuracy: 0.8725
# Epoch 5/10
# 10/10 [==============================] - 121s 12s/step - loss: 0.2370 - accuracy: 0.9089 - val_loss: 0.4020 - val_accuracy: 0.8658
# Epoch 6/10
# 10/10 [==============================] - 121s 12s/step - loss: 0.3016 - accuracy: 0.8921 - val_loss: 0.4070 - val_accuracy: 0.8389
# Epoch 7/10
# 10/10 [==============================] - 124s 12s/step - loss: 0.2709 - accuracy: 0.9039 - val_loss: 0.4170 - val_accuracy: 0.8591
# Epoch 8/10
# 10/10 [==============================] - 124s 12s/step - loss: 0.2387 - accuracy: 0.9140 - val_loss: 0.3755 - val_accuracy: 0.8658
# Epoch 9/10
# 10/10 [==============================] - 121s 12s/step - loss: 0.2222 - accuracy: 0.9191 - val_loss: 0.3658 - val_accuracy: 0.8591
# Epoch 10/10
# 10/10 [==============================] - 119s 12s/step - loss: 0.2272 - accuracy: 0.9174 - val_loss: 0.3745 - val_accuracy: 0.8658
# Begin evalutaion ...
# 3/3 [==============================] - 2s 828ms/step - loss: 0.2489 - accuracy: 0.9135
# accuracy: 91.35%
#
# HISTORY
# Test set evalutaion
# 2/2 [==============================] - 1s 617ms/step - loss: 0.3632 - accuracy: 0.8942
# accuracy: 89.42%
#
# Activity accuracy training set
# --------------------------------------------------------------------------------
# 29/29 [==============================] - 35s 1s/step
# Classwise accuracy:
# Model accuracy for predicting Eat: 94/114 || 82.46%
# Model accuracy for predicting Leave_Home: 62/62 || 100.0%
# Model accuracy for predicting Other: 440/460 || 95.65%
# Model accuracy for predicting Sleep: 77/87 || 88.51%
# Model accuracy for predicting Take_medicine: 31/40 || 77.5%
# Model accuracy for predicting Use Toiltet: 17/27 || 62.96%
# Model accuracy for predicting Wake: 77/87 || 88.51%
# Model accuracy for predicting Work: 47/50 || 94.0%
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
#
# Activity accuracy test set
# --------------------------------------------------------------------------------
# 4/4 [==============================] - 4s 969ms/step
# Classwise accuracy:
# Model accuracy for predicting Eat: 13/13 || 100.0%
# Model accuracy for predicting Leave_Home: 7/7 || 100.0%
# Model accuracy for predicting Other: 46/51 || 90.2%
# Model accuracy for predicting Sleep: 8/10 || 80.0%
# Model accuracy for predicting Take_medicine: 2/4 || 50.0%
# Model accuracy for predicting Use Toiltet: 2/3 || 66.67%
# Model accuracy for predicting Wake: 9/10 || 90.0%
# Model accuracy for predicting Work: 6/6 || 100.0%
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
