# %% [markdown]
# # EXPERIMENT 1
# ---
# ### Model Architecture: LSTM
#
# ### Parameters
# - INPUT_DIM = 1000 (arbitary, high dimension)
# - N_HIDDEN = 64
# - MAX_LENGTH = 2000 (fixed)
# - NO_ACTIVITIES = 8 (cairo fixed)
# - OPTIMIZER = ADAM
# - TOTAL EPOCHS = 50

# %%
from google.colab import drive
drive.mount('/content/drive/')
#imports
import os 
import pickle
import json
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

#tensorflow
import tensorflow as tf
from keras.layers import Dense, LSTM, Bidirectional, RNN
from keras.layers.embeddings import Embedding
from keras.models import Sequential
DATA_PATH = '/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/PP_Data/'
# Out:
# Mounted at /content/drive/
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
def getData(datasetName):
    X = np.load(f"{DATA_PATH}{datasetName}_X.npy", allow_pickle=True)
    Y = np.load(f"{DATA_PATH}{datasetName}_Y.npy", allow_pickle=True)
    enc_dec = np.load(f"{DATA_PATH}/{datasetName}_ENCDEC.npy", allow_pickle=True)
    return X, Y, enc_dec
X, y, (idx2act, idx2obs, act2idx, obs2idx) = getData('cairo')

# %%
def get_class_acc(X, y, model, idx2act):
  preds = np.array(np.argmax(model.predict(X, verbose=1), axis=-1), dtype=np.int32)
  targets = np.array(y, dtype=np.int32)
  m = confusion_matrix(targets, preds)
  fig, ax = plt.subplots(figsize=(13,10))
  sns.heatmap(m, annot=True, ax=ax)
  ax.set(xticklabels=idx2act, yticklabels=idx2act)
  plt.show()

# %%
def plot_history(dict):
  # summarize history for accuracy
  plt.figure(figsize=(10,10))
  plt.plot(dict['accuracy'])
  plt.plot(dict['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'valid'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.figure(figsize=(10,10))
  plt.plot(dict['loss'])
  plt.plot(dict['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'valid'], loc='upper left')
  plt.show()

# %%
def run(X, y, idx2act, model, save_as, EPOCHS=10):
  print("-"*100)
  print(" > REPORT")
  print("-"*100)
  # TEST SPLIT
  X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.1)

  print('Training set distribution')
  fig, ax = plt.subplots(figsize=(15,5))
  train_y_df = pd.DataFrame({'y' : np.array(y_train, dtype=np.float32)})
  sns.countplot(train_y_df.y, ax=ax)
  ax.set(xticklabels=idx2act)
  plt.show()
  print('Test set distribution')
  fig2, ax2 = plt.subplots(figsize=(15,5))
  test_y_df = pd.DataFrame({'y' : np.array(y_test, dtype=np.float32)})
  sns.countplot(test_y_df.y, ax=ax2)
  ax2.set(xticklabels=idx2act)
  plt.show()
  
  print('Activity accuracy training set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_train, dtype=np.float32)), tf.convert_to_tensor(np.array(y_train, dtype=np.float32)), model, idx2act)
  print()
  print('Activity accuracy test set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), model, idx2act)
  
  # KFOLD SETUP
  X_train_np = np.array(X_train, dtype=np.float32)
  y_train_np = np.array(y_train, dtype=np.float32)
  skf = StratifiedKFold(n_splits=5, random_state=RANDOM_SEED, shuffle=True)
  # KFOLD LOOP
  overall_acc = []
  
  agg_hist={'loss': [], 'val_loss': [], 'accuracy': [], 'val_accuracy': []}
  for i, (train, test) in enumerate(skf.split(X_train_np, y_train_np)):
    print(f'Fold >> {i+1}')
    X_train_ = tf.convert_to_tensor(X_train_np[train], dtype=tf.float32)
    Y_train_ = tf.convert_to_tensor(y_train_np[train], dtype=tf.float32)
    X_test_ = tf.convert_to_tensor(X_train_np[test], dtype=tf.float32)
    Y_test_ = tf.convert_to_tensor(y_train_np[test], dtype=tf.float32)
    print(f"Begin training ...")

    #callbacks
    filepath = f"/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/{save_as}.h5"
    history = model.fit(X_train_, Y_train_, epochs=EPOCHS, batch_size=64, verbose=1, callbacks=[], validation_split=0.2)
    agg_hist['loss'].extend(history.history['loss'])
    agg_hist['val_loss'].extend(history.history['val_loss'])
    agg_hist['accuracy'].extend(history.history['accuracy'])
    agg_hist['val_accuracy'].extend(history.history['val_accuracy'])
    print(f"Begin evalutaion ...")
    scores = model.evaluate(X_test_, Y_test_, batch_size=64, verbose=1)
    print('%s: %.2f%%' % (model.metrics_names[1], scores[1] * 100))
    overall_acc.append(scores[1]*100)
    print()

  model.save(filepath)
  print('HISTORY')
  plot_history(agg_hist)
  print()

  print('Test set evalutaion')
  scores = model.evaluate(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), batch_size=64, verbose=1)
  print('%s: %.2f%%' % (model.metrics_names[1], scores[1] * 100))
  print()
  print('Activity accuracy training set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_train, dtype=np.float32)), tf.convert_to_tensor(np.array(y_train, dtype=np.float32)), model, idx2act)
  print()
  print('Activity accuracy test set')
  print('-'*80)
  get_class_acc(tf.convert_to_tensor(np.array(X_test, dtype=np.float32)), tf.convert_to_tensor(np.array(y_test, dtype=np.float32)), model, idx2act)

# %%
# biLSTM 
def get_model(INPUT_DIM, N_HIDDEN, MAX_LENGTH, NO_ACTIVITIES, OPTIMIZER):
  model = Sequential(name='LSTM')
  model.add(Embedding(INPUT_DIM, N_HIDDEN, input_length=MAX_LENGTH, mask_zero=True))
  model.add(LSTM(N_HIDDEN))
  model.add(Dense(NO_ACTIVITIES, activation='softmax'))
  model.compile(loss='sparse_categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])
  model.summary()
  return model

# %%
#Arbitary high dim
INPUT_DIM = 1000 
#2n
N_HIDDEN = 64
MAX_LENGTH = 2000
NO_ACTIVITIES = len(idx2act)
OPTIMIZER = 'adam'

# %%
model = get_model(INPUT_DIM, N_HIDDEN, MAX_LENGTH, NO_ACTIVITIES, OPTIMIZER)
# Out:
# Model: "LSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 2000, 64)          64000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 97,544
# Trainable params: 97,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
#GO
run(X, y, idx2act, model, 'biLSTM_EP1', 10)
# Out:
# ----------------------------------------------------------------------------------------------------
#  > REPORT
# ----------------------------------------------------------------------------------------------------
# Training set distribution
# Test set distribution
# Activity accuracy training set
# --------------------------------------------------------------------------------
# 29/29 [==============================] - 9s 306ms/step
# Activity accuracy test set
# --------------------------------------------------------------------------------
# 4/4 [==============================] - 1s 254ms/step
# Fold >> 1
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - 41s 4s/step - loss: 2.0433 - accuracy: 0.4223 - val_loss: 1.9443 - val_accuracy: 0.5638
# Epoch 2/10
# 10/10 [==============================] - 40s 4s/step - loss: 1.7940 - accuracy: 0.4797 - val_loss: 1.3302 - val_accuracy: 0.5638
# Epoch 3/10
# 10/10 [==============================] - 40s 4s/step - loss: 1.5369 - accuracy: 0.5034 - val_loss: 1.2630 - val_accuracy: 0.6107
# Epoch 4/10
# 10/10 [==============================] - 39s 4s/step - loss: 1.4179 - accuracy: 0.5321 - val_loss: 1.2020 - val_accuracy: 0.6443
# Epoch 5/10
# 10/10 [==============================] - 40s 4s/step - loss: 1.3378 - accuracy: 0.5338 - val_loss: 1.0976 - val_accuracy: 0.6443
# Epoch 6/10
# 10/10 [==============================] - 39s 4s/step - loss: 1.2168 - accuracy: 0.5422 - val_loss: 0.9833 - val_accuracy: 0.6644
# Epoch 7/10
# 10/10 [==============================] - 39s 4s/step - loss: 1.1311 - accuracy: 0.5861 - val_loss: 0.9244 - val_accuracy: 0.7181
# Epoch 8/10
# 10/10 [==============================] - 39s 4s/step - loss: 1.0677 - accuracy: 0.6132 - val_loss: 0.9128 - val_accuracy: 0.6980
# Epoch 9/10
# 10/10 [==============================] - 40s 4s/step - loss: 0.9564 - accuracy: 0.6503 - val_loss: 0.8190 - val_accuracy: 0.7181
# Epoch 10/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.9216 - accuracy: 0.6622 - val_loss: 0.8456 - val_accuracy: 0.6913
# Begin evalutaion ...
# 3/3 [==============================] - 1s 226ms/step - loss: 0.9468 - accuracy: 0.6344
# accuracy: 63.44%
#
# Fold >> 2
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.8811 - accuracy: 0.6909 - val_loss: 0.7881 - val_accuracy: 0.7248
# Epoch 2/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.7902 - accuracy: 0.7162 - val_loss: 0.7743 - val_accuracy: 0.7315
# Epoch 3/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.7486 - accuracy: 0.7382 - val_loss: 0.7287 - val_accuracy: 0.7383
# Epoch 4/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.7432 - accuracy: 0.7416 - val_loss: 1.0346 - val_accuracy: 0.6107
# Epoch 5/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.9214 - accuracy: 0.6959 - val_loss: 0.7640 - val_accuracy: 0.7315
# Epoch 6/10
# 10/10 [==============================] - 40s 4s/step - loss: 0.7938 - accuracy: 0.7111 - val_loss: 0.7628 - val_accuracy: 0.6980
# Epoch 7/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.7069 - accuracy: 0.7432 - val_loss: 0.6690 - val_accuracy: 0.7517
# Epoch 8/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.6590 - accuracy: 0.7635 - val_loss: 0.6493 - val_accuracy: 0.7383
# Epoch 9/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.6066 - accuracy: 0.7872 - val_loss: 0.6631 - val_accuracy: 0.7315
# Epoch 10/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.6011 - accuracy: 0.7956 - val_loss: 0.7522 - val_accuracy: 0.7584
# Begin evalutaion ...
# 3/3 [==============================] - 1s 219ms/step - loss: 0.7452 - accuracy: 0.7366
# accuracy: 73.66%
#
# Fold >> 3
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.6830 - accuracy: 0.8010 - val_loss: 0.6375 - val_accuracy: 0.7517
# Epoch 2/10
# 10/10 [==============================] - 40s 4s/step - loss: 0.5732 - accuracy: 0.8162 - val_loss: 0.6004 - val_accuracy: 0.7383
# Epoch 3/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5779 - accuracy: 0.8111 - val_loss: 0.6569 - val_accuracy: 0.7517
# Epoch 4/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.7638 - accuracy: 0.7437 - val_loss: 0.6300 - val_accuracy: 0.7987
# Epoch 5/10
# 10/10 [==============================] - 40s 4s/step - loss: 0.7152 - accuracy: 0.7656 - val_loss: 0.6008 - val_accuracy: 0.7852
# Epoch 6/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.6429 - accuracy: 0.7673 - val_loss: 0.6225 - val_accuracy: 0.7584
# Epoch 7/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.6017 - accuracy: 0.7926 - val_loss: 0.5721 - val_accuracy: 0.7852
# Epoch 8/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5871 - accuracy: 0.7774 - val_loss: 0.6360 - val_accuracy: 0.7383
# Epoch 9/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5576 - accuracy: 0.7993 - val_loss: 0.6051 - val_accuracy: 0.7919
# Epoch 10/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5442 - accuracy: 0.8111 - val_loss: 0.5660 - val_accuracy: 0.7852
# Begin evalutaion ...
# 3/3 [==============================] - 1s 216ms/step - loss: 0.6575 - accuracy: 0.7730
# accuracy: 77.30%
#
# Fold >> 4
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5465 - accuracy: 0.7960 - val_loss: 0.6665 - val_accuracy: 0.7517
# Epoch 2/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5266 - accuracy: 0.8044 - val_loss: 0.6726 - val_accuracy: 0.7718
# Epoch 3/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5297 - accuracy: 0.8094 - val_loss: 0.6495 - val_accuracy: 0.7651
# Epoch 4/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5878 - accuracy: 0.8044 - val_loss: 0.7302 - val_accuracy: 0.7315
# Epoch 5/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5591 - accuracy: 0.7909 - val_loss: 0.6647 - val_accuracy: 0.7517
# Epoch 6/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5173 - accuracy: 0.8111 - val_loss: 0.7234 - val_accuracy: 0.7584
# Epoch 7/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5056 - accuracy: 0.8128 - val_loss: 0.6736 - val_accuracy: 0.7785
# Epoch 8/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.4857 - accuracy: 0.8212 - val_loss: 0.7336 - val_accuracy: 0.7517
# Epoch 9/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.4677 - accuracy: 0.8297 - val_loss: 0.6679 - val_accuracy: 0.7718
# Epoch 10/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.4854 - accuracy: 0.8297 - val_loss: 0.6532 - val_accuracy: 0.7852
# Begin evalutaion ...
# 3/3 [==============================] - 1s 221ms/step - loss: 0.4637 - accuracy: 0.8216
# accuracy: 82.16%
#
# Fold >> 5
# Begin training ...
# Epoch 1/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.4346 - accuracy: 0.8432 - val_loss: 0.6897 - val_accuracy: 0.7517
# Epoch 2/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.4255 - accuracy: 0.8516 - val_loss: 0.6570 - val_accuracy: 0.7651
# Epoch 3/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.4449 - accuracy: 0.8364 - val_loss: 0.7767 - val_accuracy: 0.7114
# Epoch 4/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5019 - accuracy: 0.8111 - val_loss: 0.6961 - val_accuracy: 0.7383
# Epoch 5/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5065 - accuracy: 0.7993 - val_loss: 0.7723 - val_accuracy: 0.6846
# Epoch 6/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.5125 - accuracy: 0.7875 - val_loss: 0.6672 - val_accuracy: 0.7315
# Epoch 7/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.4309 - accuracy: 0.8398 - val_loss: 0.6640 - val_accuracy: 0.7517
# Epoch 8/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.4313 - accuracy: 0.8314 - val_loss: 0.6619 - val_accuracy: 0.7517
# Epoch 9/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.4139 - accuracy: 0.8432 - val_loss: 0.6987 - val_accuracy: 0.7584
# Epoch 10/10
# 10/10 [==============================] - 39s 4s/step - loss: 0.4071 - accuracy: 0.8499 - val_loss: 0.6618 - val_accuracy: 0.7584
# Begin evalutaion ...
# 3/3 [==============================] - 1s 216ms/step - loss: 0.4638 - accuracy: 0.8324
# accuracy: 83.24%
#
# HISTORY
# Test set evalutaion
# 2/2 [==============================] - 0s 166ms/step - loss: 0.5950 - accuracy: 0.7788
# accuracy: 77.88%
#
# Activity accuracy training set
# --------------------------------------------------------------------------------
# 29/29 [==============================] - 9s 301ms/step
# Activity accuracy test set
# --------------------------------------------------------------------------------
# 4/4 [==============================] - 1s 236ms/step
