# %% [markdown]
# # SETUP

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#imports
import os 
import pickle
import json
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

#tensorflow
import tensorflow as tf
from keras.layers import Dense, LSTM, Bidirectional, RNN
from keras.layers.embeddings import Embedding
from keras.models import Sequential
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
DATA_PATH = '/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/PP_Data/'

# %%
# !nvidia-smi
# Out:
# Thu Sep 17 11:34:11 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # JS to keep Colab running
# `
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)
# `

# %% [markdown]
# # LOAD DATA

# %%
def getData(datasetName):
    X = np.load(f"{DATA_PATH}{datasetName}_X.npy", allow_pickle=True)
    Y = np.load(f"{DATA_PATH}{datasetName}_Y.npy", allow_pickle=True)
    enc_dec = np.load(f"{DATA_PATH}/{datasetName}_ENCDEC.npy", allow_pickle=True)
    return X, Y, enc_dec

# %%
X, Y, (idx2act, idx2obs, act2idx, obs2idx) = getData('cairo')

# %% [markdown]
# # EDA

# %%
i = [1, 3, 4 ,5 ]
print('Example of input')
print('-'*40)
print()
for idx in i:
  print(f"sequence of sensor activations: {X[idx]}")
  print(f"activity: {Y[idx]}")
  print()
# Out:
# Example of input
# ----------------------------------------
#
# sequence of sensor activations: [ 0  0  0 ...  9 16  8]
# activity: 5
#
# sequence of sensor activations: [ 0  0  0 ... 46 47 46]
# activity: 6
#
# sequence of sensor activations: [ 0  0  0 ... 43 42 68]
# activity: 2
#
# sequence of sensor activations: [ 0  0  0 ... 18 27 26]
# activity: 6

# %%
fig, ax = plt.subplots(figsize=(14,7))
sns.countplot(Y, ax=ax, palette=sns.color_palette('Blues', 8))
ax.set(xticklabels=idx2act, title = "Activity distribution of cairo dataset")
# Out:
# [[Text(0, 0, 'Eat'),
#   Text(0, 0, 'Leave_Home'),
#   Text(0, 0, 'Other'),
#   Text(0, 0, 'Sleep'),
#   Text(0, 0, 'Take_medicine'),
#   Text(0, 0, 'Use Toiltet'),
#   Text(0, 0, 'Wake'),
#   Text(0, 0, 'Work')],
#  Text(0.5, 1.0, 'Activity distribution of cairo dataset')]

# %% [markdown]
# # TEST DATA SPLIT

# %%
split_point = int(0.1 * len(X))
X_test = X[:split_point]
Y_test = Y[:split_point]
X_train = X[split_point:]
Y_train = Y[split_point:]

print(f"Train set size: {len(X_train)}")
print(f"Test set size: {len(X_test)}")
# Out:
# Train set size: 928
# Test set size: 103

# %% [markdown]
# # MODEL ARCH

# %%
# biLSTM 
def get_biLSTM(INPUT_DIM, N_HIDDEN, MAX_LENGTH, NO_ACTIVITIES, OPTIMIZER):
  model = Sequential(name='biLSTM')
  model.add(Embedding(INPUT_DIM, N_HIDDEN, input_length=MAX_LENGTH, mask_zero=True))
  model.add(Bidirectional(LSTM(N_HIDDEN)))
  model.add(Dense(NO_ACTIVITIES, activation='softmax'))
  model.compile(loss='sparse_categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])
  model.summary()
  return model

# %%
INPUT_DIM = len(X)
NO_ACTIVITIES = len(np.unique(Y))
MAX_LENGTH = 2000
N_HIDDEN = 64
OPTIMIZER = 'adam'
EPOCHS = 50

# %%
model = get_biLSTM(INPUT_DIM, N_HIDDEN, MAX_LENGTH, NO_ACTIVITIES, OPTIMIZER)
# Out:
# Model: "biLSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2000, 64)          65984
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               66048
# _________________________________________________________________
# dense (Dense)                (None, 8)                 1032
# =================================================================
# Total params: 133,064
# Trainable params: 133,064
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pwd
# Out:
# /content

# %%
# setup-settings:
config = {
    "name" : model.name,
    "epochs" : EPOCHS,
    "n_hidden" : N_HIDDEN,
    "input_dim" : INPUT_DIM,
    "opt": OPTIMIZER,
    "summary": model.get_config()
}
with open('config.json', 'w') as fp:
    json.dump(config, fp)

# %% [markdown]
# # Training

# %%
X_np = np.array(X_train, dtype=np.int32)
Y_np = np.array(Y_train, dtype=np.int32)

# %%
X_tensor = tf.convert_to_tensor(X_np, dtype=tf.float32)
Y_tensor = tf.convert_to_tensor(Y_np, dtype=tf.float32)

# %%
history = model.fit(X_tensor, Y_tensor, validation_split=0.2, batch_size=64, verbose=1, epochs=EPOCHS)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 135s 11s/step - loss: 2.0084 - accuracy: 0.4259 - val_loss: 1.8665 - val_accuracy: 0.4946
# Epoch 2/50
# 12/12 [==============================] - 133s 11s/step - loss: 1.5999 - accuracy: 0.4946 - val_loss: 1.5100 - val_accuracy: 0.4946
# Epoch 3/50
# 12/12 [==============================] - 134s 11s/step - loss: 1.3779 - accuracy: 0.4973 - val_loss: 1.3323 - val_accuracy: 0.5054
# Epoch 4/50
# 12/12 [==============================] - 134s 11s/step - loss: 1.1215 - accuracy: 0.6146 - val_loss: 1.0992 - val_accuracy: 0.6935
# Epoch 5/50
# 12/12 [==============================] - 135s 11s/step - loss: 0.9246 - accuracy: 0.7183 - val_loss: 0.9719 - val_accuracy: 0.6882
# Epoch 6/50
# 12/12 [==============================] - 137s 11s/step - loss: 0.7864 - accuracy: 0.7520 - val_loss: 0.8502 - val_accuracy: 0.7043
# Epoch 7/50
# 12/12 [==============================] - 138s 11s/step - loss: 0.6763 - accuracy: 0.7628 - val_loss: 0.7521 - val_accuracy: 0.7258
# Epoch 8/50
# 12/12 [==============================] - 137s 11s/step - loss: 0.5987 - accuracy: 0.8019 - val_loss: 0.6601 - val_accuracy: 0.7258
# Epoch 9/50
# 12/12 [==============================] - 136s 11s/step - loss: 0.5135 - accuracy: 0.8140 - val_loss: 0.6095 - val_accuracy: 0.7581
# Epoch 10/50
# 12/12 [==============================] - 134s 11s/step - loss: 0.4536 - accuracy: 0.8544 - val_loss: 0.5444 - val_accuracy: 0.7849
# Epoch 11/50
# 12/12 [==============================] - 134s 11s/step - loss: 0.4207 - accuracy: 0.8706 - val_loss: 0.5253 - val_accuracy: 0.8172
# Epoch 12/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.3882 - accuracy: 0.8693 - val_loss: 0.5317 - val_accuracy: 0.8280
# Epoch 13/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.3588 - accuracy: 0.8787 - val_loss: 0.4744 - val_accuracy: 0.8441
# Epoch 14/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.3273 - accuracy: 0.8989 - val_loss: 0.4888 - val_accuracy: 0.8387
# Epoch 15/50
# 12/12 [==============================] - 132s 11s/step - loss: 0.2980 - accuracy: 0.9057 - val_loss: 0.4899 - val_accuracy: 0.8280
# Epoch 16/50
# 12/12 [==============================] - 132s 11s/step - loss: 0.3048 - accuracy: 0.8895 - val_loss: 0.4370 - val_accuracy: 0.8548
# Epoch 17/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.2912 - accuracy: 0.8962 - val_loss: 0.5820 - val_accuracy: 0.7742
# Epoch 18/50
# 12/12 [==============================] - 131s 11s/step - loss: 0.3327 - accuracy: 0.8760 - val_loss: 0.4339 - val_accuracy: 0.8172
# Epoch 19/50
# 12/12 [==============================] - 132s 11s/step - loss: 0.2873 - accuracy: 0.9070 - val_loss: 0.4542 - val_accuracy: 0.8441
# Epoch 20/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.2553 - accuracy: 0.9245 - val_loss: 0.4103 - val_accuracy: 0.8602
# Epoch 21/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.2456 - accuracy: 0.9097 - val_loss: 0.4246 - val_accuracy: 0.8441
# Epoch 22/50
# 12/12 [==============================] - 134s 11s/step - loss: 0.2441 - accuracy: 0.9097 - val_loss: 0.4324 - val_accuracy: 0.8172
# Epoch 23/50
# 12/12 [==============================] - 132s 11s/step - loss: 0.2716 - accuracy: 0.9043 - val_loss: 0.3642 - val_accuracy: 0.8602
# Epoch 24/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.2325 - accuracy: 0.9164 - val_loss: 0.3588 - val_accuracy: 0.8656
# Epoch 25/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.2176 - accuracy: 0.9191 - val_loss: 0.4033 - val_accuracy: 0.8387
# Epoch 26/50
# 12/12 [==============================] - 132s 11s/step - loss: 0.2090 - accuracy: 0.9245 - val_loss: 0.3188 - val_accuracy: 0.8817
# Epoch 27/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.1871 - accuracy: 0.9353 - val_loss: 0.3155 - val_accuracy: 0.8871
# Epoch 28/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.1761 - accuracy: 0.9434 - val_loss: 0.4123 - val_accuracy: 0.8817
# Epoch 29/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.2104 - accuracy: 0.9286 - val_loss: 0.3683 - val_accuracy: 0.8871
# Epoch 30/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.1615 - accuracy: 0.9461 - val_loss: 0.3848 - val_accuracy: 0.8978
# Epoch 31/50
# 12/12 [==============================] - 133s 11s/step - loss: 0.1567 - accuracy: 0.9461 - val_loss: 0.3408 - val_accuracy: 0.8871
# Epoch 32/50
# 12/12 [==============================] - 134s 11s/step - loss: 0.1788 - accuracy: 0.9340 - val_loss: 0.3886 - val_accuracy: 0.8656
# Epoch 33/50
# 12/12 [==============================] - 134s 11s/step - loss: 0.1598 - accuracy: 0.9474 - val_loss: 0.4215 - val_accuracy: 0.8656
# Epoch 34/50
# 12/12 [==============================] - 134s 11s/step - loss: 0.1566 - accuracy: 0.9501 - val_loss: 0.4068 - val_accuracy: 0.8387
# Epoch 35/50
# 12/12 [==============================] - 135s 11s/step - loss: 0.1966 - accuracy: 0.9299 - val_loss: 0.3709 - val_accuracy: 0.8763
# Epoch 36/50
# 12/12 [==============================] - 134s 11s/step - loss: 0.1523 - accuracy: 0.9501 - val_loss: 0.3564 - val_accuracy: 0.8871
# Epoch 37/50
# 12/12 [==============================] - 136s 11s/step - loss: 0.1964 - accuracy: 0.9353 - val_loss: 0.4939 - val_accuracy: 0.8065
# Epoch 38/50
# 12/12 [==============================] - 137s 11s/step - loss: 0.2583 - accuracy: 0.9097 - val_loss: 0.3912 - val_accuracy: 0.8763
# Epoch 39/50
# 12/12 [==============================] - 138s 11s/step - loss: 0.2106 - accuracy: 0.9394 - val_loss: 0.3997 - val_accuracy: 0.8656
# Epoch 40/50
# 12/12 [==============================] - 136s 11s/step - loss: 0.1927 - accuracy: 0.9407 - val_loss: 0.3796 - val_accuracy: 0.8763
# Epoch 41/50
# 12/12 [==============================] - 134s 11s/step - loss: 0.1844 - accuracy: 0.9474 - val_loss: 0.3616 - val_accuracy: 0.8871
# Epoch 42/50
# 12/12 [==============================] - 137s 11s/step - loss: 0.1691 - accuracy: 0.9447 - val_loss: 0.3522 - val_accuracy: 0.8978
# Epoch 43/50
# 12/12 [==============================] - 137s 11s/step - loss: 0.1524 - accuracy: 0.9488 - val_loss: 0.3661 - val_accuracy: 0.8925
# Epoch 44/50
# 12/12 [==============================] - 137s 11s/step - loss: 0.2179 - accuracy: 0.9326 - val_loss: 0.3276 - val_accuracy: 0.8925
# Epoch 45/50
# 12/12 [==============================] - 138s 12s/step - loss: 0.1623 - accuracy: 0.9528 - val_loss: 0.3024 - val_accuracy: 0.9032
# Epoch 46/50
# 12/12 [==============================] - 136s 11s/step - loss: 0.1850 - accuracy: 0.9420 - val_loss: 0.3461 - val_accuracy: 0.8978
# Epoch 47/50
# 12/12 [==============================] - 137s 11s/step - loss: 0.1743 - accuracy: 0.9367 - val_loss: 0.3436 - val_accuracy: 0.8871
# Epoch 48/50
# 12/12 [==============================] - 137s 11s/step - loss: 0.1638 - accuracy: 0.9461 - val_loss: 0.3680 - val_accuracy: 0.8925
# Epoch 49/50
# 12/12 [==============================] - 136s 11s/step - loss: 0.1578 - accuracy: 0.9569 - val_loss: 0.3184 - val_accuracy: 0.8925
# Epoch 50/50
# 12/12 [==============================] - 135s 11s/step - loss: 0.1442 - accuracy: 0.9596 - val_loss: 0.3204 - val_accuracy: 0.9140

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
def get_class_acc(X_test, Y_test, model, idx2act):
  preds = np.array(np.argmax(model.predict(X_test), axis=-1), dtype=np.int32)
  targets = np.array(Y_test, dtype=np.int32)
  correct = {}
  total = {}
  for i in range(len(idx2act)):
    correct[i] = 1 
    total[i] = 1
  for i, pred in enumerate(preds):
    if pred == targets[i]:
      correct[pred] +=1
    total[pred]+=1
  
  for i, act in enumerate(idx2act):
    print(f"{act} : {correct[i]}/{total[i]}  [{round(correct[i]/total[i]*100,2)} %]")

# %%
get_class_acc(X_tensor, Y_tensor, model, idx2act)
# Out:
# Eat : 104/106  [98.11 %]
# Leave_Home : 64/65  [98.46 %]
# Other : 440/452  [97.35 %]
# Sleep : 82/89  [92.13 %]
# Take_medicine : 37/44  [84.09 %]
# Use Toiltet : 28/33  [84.85 %]
# Wake : 82/90  [91.11 %]
# Work : 53/57  [92.98 %]

# %% [markdown]
# # Evaluation

# %%
X_np_test = np.array(X_test, dtype=np.int32)
Y_np_test = np.array(Y_test, dtype=np.int32)
X_tensor_test = tf.convert_to_tensor(X_np_test, dtype=tf.float32)
Y_tensor_test = tf.convert_to_tensor(Y_np_test, dtype=tf.float32)

# %%
scores = model.evaluate(X_tensor_test, Y_tensor_test, batch_size=64, verbose=1)
print('%s: %.2f%%' % (model.metrics_names[1], scores[1] * 100))
# Out:
# 2/2 [==============================] - 1s 574ms/step - loss: 0.7946 - accuracy: 0.7379
# accuracy: 73.79%

# %%
get_class_acc(X_tensor_test, Y_tensor_test, model, idx2act)
# Out:
# Eat : 8/13  [61.54 %]
# Leave_Home : 7/8  [87.5 %]
# Other : 45/55  [81.82 %]
# Sleep : 8/11  [72.73 %]
# Take_medicine : 4/4  [100.0 %]
# Use Toiltet : 2/6  [33.33 %]
# Wake : 8/10  [80.0 %]
# Work : 2/4  [50.0 %]

# %% [markdown]
# # CHECKPOINT

# %%
save_as = "biLSTM-50ep"
filepath = f"/content/drive/My Drive/Research/Deeplearning-in-IoT-systems/Experiments/Models/{save_as}.h5"
model.save(filepath)

# %% [markdown]
# ## TESTS

# %%
preds = list(np.array(np.argmax(model.predict(X_tensor), axis=-1), dtype=np.int32))

# %%
targets = list(np.array(Y_tensor, dtype=np.int32))

# %%
fig, ax = plt.subplots(figsize=(16,15))
sns.heatmap(confusion_matrix(targets, preds), annot=True, ax=ax)
ax.set(xticklabels=idx2act, yticklabels=idx2act)
# Out:
# [[Text(0, 0.5, 'Eat'),
#   Text(0, 1.5, 'Leave_Home'),
#   Text(0, 2.5, 'Other'),
#   Text(0, 3.5, 'Sleep'),
#   Text(0, 4.5, 'Take_medicine'),
#   Text(0, 5.5, 'Use Toiltet'),
#   Text(0, 6.5, 'Wake'),
#   Text(0, 7.5, 'Work')],
#  [Text(0.5, 0, 'Eat'),
#   Text(1.5, 0, 'Leave_Home'),
#   Text(2.5, 0, 'Other'),
#   Text(3.5, 0, 'Sleep'),
#   Text(4.5, 0, 'Take_medicine'),
#   Text(5.5, 0, 'Use Toiltet'),
#   Text(6.5, 0, 'Wake'),
#   Text(7.5, 0, 'Work')]]
